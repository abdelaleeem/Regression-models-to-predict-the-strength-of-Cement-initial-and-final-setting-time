# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("D:\internship data\intern data.xlsx" , sheet_name = "cleaned data" ).drop(columns=["Class", 'Unnamed: 31', 'diff' , 'IR.', 'CaOfree', "Cl"])
df
# Out:
#        SiO2  Al2O3  Fe2O3    CaO   MgO   SO3   K2O  Na2O   LOI  A.Eq  Total  \
# 0     19.43   4.38   3.59  61.77  2.84  3.29  0.40  0.29  3.16  0.55  99.19
# 1     19.49   4.62   3.57  61.93  2.89  3.03  0.40  0.30  3.33  0.56  99.60
# 2     19.69   4.29   4.06  60.93  2.66  3.19  0.35  0.28  2.88  0.51  98.37
# 3     18.88   4.41   3.54  61.84  2.80  3.16  0.43  0.31  3.42  0.59  98.83
# 4     19.22   4.25   3.74  61.65  2.83  3.02  0.41  0.28  3.28  0.55  98.72
# ...     ...    ...    ...    ...   ...   ...   ...   ...   ...   ...    ...
# 1446  20.52   4.39   4.69  59.68  3.57  3.00  0.30  0.23  3.40  0.43  99.82
# 1447  20.41   4.36   4.67  59.73  3.51  3.52  0.30  0.23  2.77  0.43  99.54
# 1448  20.56   4.38   4.68  59.85  3.90  3.06  0.31  0.24  2.60  0.44  99.62
# 1449  21.86   6.38   4.14  55.71  4.07  3.46  0.34  0.21  3.10  0.43  99.31
# 1450  20.44   4.04   4.52  59.22  3.29  3.53  0.28  0.22  3.22  0.40  98.80
#
#         LSF    SM    AM    C3S    C2S   C3A   C4AF     %  Initial  Final  \
# 0     96.06  2.44  1.22  59.83  10.59  5.54  10.91  25.2      170    265
# 1     95.93  2.38  1.29  59.18  11.25  6.21  10.85  25.0      160    265
# 2     93.42  2.36  1.06  54.65  15.24  4.51  12.34  25.0      165    265
# 3     98.77  2.37  1.25  64.54   5.47  5.70  10.76  24.8      170    265
# 4     97.18  2.41  1.14  62.36   8.08  4.94  11.37  24.8      160    270
# ...     ...   ...   ...    ...    ...   ...    ...   ...      ...    ...
# 1446  87.66  2.26  0.94  42.23  26.99  3.71  14.26  26.0      170    235
# 1447  87.66  2.26  0.93  42.01  26.84  3.66  14.20  26.0      175    245
# 1448  87.73  2.27  0.94  42.52  26.88  3.70  14.23  26.2      165    240
# 1449  74.60  2.08  1.54   2.01  61.16  9.91  12.59  25.8      175    260
# 1450  87.39  2.39  0.89  42.04  26.90  3.07  13.74  25.8      165    235
#
#        2 d  28 d  Blaine  45 m R  90 m R  Cao_free
# 0     21.3  46.5    3290    18.3     2.7      1.22
# 1     21.3  45.9    3320    20.5     4.1      1.35
# 2     20.5  46.4    3290    18.7     3.2      1.40
# 3     21.9  47.3    3340    18.7     3.5      1.30
# 4     22.0  46.3    3160    19.5     3.5      1.64
# ...    ...   ...     ...     ...     ...       ...
# 1446  21.6  48.6    3710    19.8     4.2       NaN
# 1447  19.5  47.1    3570    17.6     3.8       NaN
# 1448  22.6  48.3    3210    21.9     4.1       NaN
# 1449  21.7  47.5    3720    16.3     3.3       NaN
# 1450  20.4  45.4    3850    17.0     2.0       NaN
#
# [1451 rows x 27 columns]

# %% [markdown]
# ## Now Let's Explore Some Data Statistics

# %%
df.describe()
# Out:
#               SiO2        Al2O3        Fe2O3          CaO          MgO  \
# count  1451.000000  1451.000000  1451.000000  1451.000000  1451.000000
# mean     19.413887     4.246106     3.897905    61.244094     2.954176
# std       0.503901     0.193082     0.243992     0.647538     0.342582
# min      18.030000     3.600000     3.410000    55.710000     2.090000
# 25%      19.100000     4.120000     3.710000    60.940000     2.730000
# 50%      19.350000     4.250000     3.850000    61.330000     2.930000
# 75%      19.650000     4.370000     4.060000    61.660000     3.140000
# max      21.910000     6.380000     4.900000    63.010000     4.100000
#
#                SO3          K2O         Na2O          LOI         A.Eq  \
# count  1451.000000  1451.000000  1451.000000  1451.000000  1451.000000
# mean      3.117884     0.341633     0.304521     3.450069     0.528952
# std       0.171677     0.065518     0.093945     0.323469     0.112260
# min       2.130000     0.150000     0.150000     1.650000     0.250000
# 25%       3.020000     0.300000     0.240000     3.270000     0.450000
# 50%       3.120000     0.350000     0.270000     3.480000     0.520000
# 75%       3.230000     0.380000     0.360000     3.670000     0.600000
# max       3.690000     0.530000     0.670000     4.720000     0.980000
#
#              Total          LSF           SM           AM          C3S  \
# count  1451.000000  1451.000000  1451.000000  1451.000000  1451.000000
# mean     99.009552    95.477085     2.385107     1.094266    58.761385
# std       0.635749     2.813598     0.060900     0.091452     5.955747
# min      96.010000    74.600000     2.050000     0.830000     2.010000
# 25%      98.595000    94.470000     2.350000     1.020000    56.940000
# 50%      99.010000    95.910000     2.380000     1.100000    59.900000
# 75%      99.440000    97.230000     2.420000     1.170000    62.275000
# max     101.000000   101.210000     2.600000     1.540000    70.010000
#
#                C2S          C3A         C4AF            %      Initial  \
# count  1451.000000  1451.000000  1451.000000  1451.000000  1451.000000
# mean     11.353129     4.664631    11.849083    25.324879   158.050310
# std       5.775811     0.726038     0.741561     0.496978     9.472841
# min       0.410000     2.360000    10.360000    23.800000   130.000000
# 25%       7.925000     4.160000    11.280000    25.000000   150.000000
# 50%      10.350000     4.750000    11.700000    25.400000   160.000000
# 75%      13.300000     5.230000    12.340000    25.600000   165.000000
# max      61.160000     9.910000    14.900000    28.000000   185.000000
#
#              Final          2 d         28 d       Blaine       45 m R  \
# count  1451.000000  1451.000000  1451.000000  1451.000000  1451.000000
# mean    255.656788    19.980703    45.766988  3222.364576    19.634114
# std       9.879309     1.375981     1.037267   158.323475     2.023885
# min     220.000000    16.000000    42.500000  2870.000000     6.600000
# 25%     250.000000    18.900000    45.100000  3130.000000    18.600000
# 50%     255.000000    20.000000    45.700000  3190.000000    19.800000
# 75%     260.000000    21.000000    46.400000  3270.000000    20.800000
# max     285.000000    23.700000    49.500000  4190.000000    26.400000
#
#             90 m R    Cao_free
# count  1451.000000  153.000000
# mean      4.237905    1.385948
# std       0.902806    0.251988
# min       0.500000    1.000000
# 25%       3.700000    1.240000
# 50%       4.300000    1.360000
# 75%       4.800000    1.460000
# max       7.900000    3.290000

# %% [markdown]
# ## Let's Create a Function To Remove The Outliers with Three Standard Deviations Method

# %%
def remove_outliers_std(df):
    df_no_outliers = df.copy()
    numerical_columns = df.select_dtypes(include='number').columns
    
    for col in numerical_columns:
        mean = df[col].mean()
        std_dev = df[col].std()
        lower_bound = mean - 3 * std_dev
        upper_bound = mean + 3 * std_dev
        
        # Filter the data
        mask = (df_no_outliers[col] >= lower_bound) & (df_no_outliers[col] <= upper_bound)
        df_no_outliers = df_no_outliers[mask]
    
    return df_no_outliers

df_no_outliers = remove_outliers_std(df)

# %%
df_no_outliers.shape
# Out:
# (152, 27)

# %% [markdown]
# ## Removing The Outliers Was Very Important For The Next Step (Finding The Correlation Coefficient Between 28 Days Strength Column And Other Columns)
# ## Removing The Outliers reduced the Size of the dataset greatly but I do this only to know the correlation coefficient then I Will Remove The Outliers Only From The Features Selected.
# ----------------------------
# ## NOTE: whenever the coefficient is closer to 1 then it's directly proportional to the target and if it's closer to -1 then it's inversly proportional

# %%
corr = df_no_outliers.corr(method = "spearman")

# %%
plt.figure(figsize=(15 , 10))
sns.heatmap(np.abs(corr[["28 d"]]).sort_values(ascending=True,by="28 d" ) , annot = True , cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## CaO Free is directly proportional with 28 d which is Pure NONESENSE so let's check the scatterplot then we shall remove it

# %% [markdown]
# ## Let's Validate the correlation heatmap results with scatterplots

# %%
# Set up subplots to create a histogram for each column
plt.figure(figsize=(15 , 20))
num_columns = len(df_no_outliers.columns)
num_rows = int(np.ceil(num_columns / 2))

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 2.5 * num_rows))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over columns and create histplot for each
for i, column in enumerate(df_no_outliers.columns):
    if column != '28 d':
        sns.regplot(data=df_no_outliers, x=df_no_outliers[column], y=df_no_outliers['28 d'], ax=axes[i])
        axes[i].set_title(f'scatter plot of {column} vs 28 days strength')
        axes[i].set_ylabel('28 d')
        axes[i].set_xlabel(f'{column}')

# Adjust layout
#plt.figure(figsize=(16, 8))    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## We could see that all the relations there are Linear relationships and the plots are interpreting the correlation heatmap

# %% [markdown]
# ## Now let's take a look at the data distribution to gain some visualized insights about our data and the range and distribution for each column

# %%
# Set up subplots to create a histogram for each column
num_columns = len(df_no_outliers.columns)
num_rows = int(np.ceil(num_columns / 2))

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 2.5 * num_rows))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over columns and create histplot for each
for i, column in enumerate(df_no_outliers.columns):
    sns.histplot(df_no_outliers[column], kde=True, stat="percent" ,ax=axes[i], color='skyblue', edgecolor='black')
    axes[i].set_title(f'Histogram of {column}')
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Density Percentages')

# Adjust layout
#plt.figure(figsize=(16, 8))    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The distributions says that there're 2 persons working per day and each person tries to achieve the KPIs of Quality with different prespective as the distribution is wavy

# %% [markdown]
# ## For Modeling Phase I want to extract the features that has above 0.05 Correlation Coefficient to Include them in my model EXCEPT CAO_FREE

# %%
pot_feats = list(corr[np.abs(corr[["28 d"]]) > 0.05]["28 d"].dropna().index)
pot_feats.remove("Cao_free")

# %%
pot_feats
# Out:
# ['CaO',
#  'K2O',
#  'LOI',
#  'SM',
#  'C3S',
#  '%',
#  'Final',
#  '2 d',
#  '28 d',
#  'Blaine',
#  '45 m R',
#  '90 m R']

# %% [markdown]
# ## Let's Remove Multi-Collinearity in our Features
# ## Multi-Collinearity --> means that our features are highly correlated with each other and that may estimate the coefficients wrong and we will lose the interpretability

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_no_outliers[pot_feats].corr() , annot = True, cmap = 'coolwarm',fmt='.1f', linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Let's color the highly correlated columns with black color (I chose the correlation coefficient threshold to be > 0.7)

# %%
sns.heatmap(np.abs(df_no_outliers[pot_feats].corr())<0.7)
# Out:
# <Axes: >

# %% [markdown]
# ## Let's Remove the features that's highly correlated with the other

# %%
correlation_matrix = df_no_outliers.corr().abs()

# Choose the threshold for correlation
threshold = 0.7

# Find index pairs where the correlation is above the threshold
high_corr_var = np.where(correlation_matrix > threshold)
high_corr_var = [(correlation_matrix.columns[x], correlation_matrix.columns[y]) 
                 for x, y in zip(*high_corr_var) if x != y and x < y]
print(high_corr_var)
# Drop one of the features in each highly correlated pair
for x, y in high_corr_var:
    if x in df_no_outliers.columns:
        df_no_outliers.drop(x, axis=1, inplace=True)
# Out:
# [('SiO2', 'LSF'), ('SiO2', 'C3S'), ('SiO2', 'C2S'), ('Al2O3', 'AM'), ('Al2O3', 'C3A'), ('Fe2O3', 'AM'), ('Fe2O3', 'C3A'), ('Fe2O3', 'C4AF'), ('K2O', 'A.Eq'), ('Na2O', 'A.Eq'), ('LSF', 'C3S'), ('LSF', 'C2S'), ('AM', 'C3A'), ('AM', 'C4AF'), ('C3S', 'C2S'), ('C3A', 'C4AF')]

# %%
df_no_outliers.columns
# Out:
# Index(['CaO', 'MgO', 'SO3', 'LOI', 'A.Eq', 'Total', 'SM', 'C2S', 'C4AF', '%',
#        'Initial', 'Final', '2 d', '28 d', 'Blaine', '45 m R', '90 m R',
#        'Cao_free'],
#       dtype='object')

# %%
plt.figure(figsize=(25,5))
sns.heatmap(df_no_outliers.corr() , annot = True, cmap = 'coolwarm',fmt='.1f', linewidths=0.5)
# Out:
# <Axes: >

# %%
filtered_feats = list(corr[np.abs(df_no_outliers.corr()[["28 d"]]) >= 0.05]["28 d"].dropna().index)
filtered_feats.remove('Final')
filtered_feats.remove('28 d')
filtered_feats.remove('Cao_free')
filtered_feats.remove('C4AF')
filtered_feats
# Out:
# ['CaO', 'LOI', 'SM', '2 d', 'Blaine', '45 m R', '90 m R']

# %% [markdown]
# ## After All of this we noticed some amazing insights:
# 1. C4AF doesn't affect strength but it's there with a coefficient of approximately -0.1 (inversly proportion) and my interpretaion is if the other phases are high in percentage (C3S , C2S , C3A) then C4AF is low in percentage which means better strength and vise-versa
#
# 2. We can't find C3S in our features and Noticed in scatterplot and correlation heatmap that they barely affect the strength which isn't logical according to the chemistry of the Cement
#
# 3. Free Lime affects in proportional way not inversely way to the strength which again isn't logical
#
# 4. there's a high correlation between 45 mR and 90 mR so we can remove one of them and i will remove 45 mR

# %%
filtered_feats.remove('45 m R')
filtered_feats
# Out:
# ['CaO', 'LOI', 'SM', '2 d', 'Blaine', '90 m R']

# %% [markdown]
# ## NOW Let's Import Our Package for Regression Modeling
# ## Note : I will focus more on Mathematical Equation to Furtherly Use It in Optimization problems BUT don't worry we will try out trees, Nearest Neighbours and SVM

# %%
# for building linear regression models and preparing data
from sklearn.linear_model import LinearRegression, Ridge , Lasso
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MinMaxScaler
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import  mean_absolute_error, mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor , AdaBoostRegressor , ExtraTreesRegressor 
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
df_no_outliers = remove_outliers_std(pd.concat([df[filtered_feats] , df["28 d"]] , axis = 1))
df_no_outliers
# Out:
#         CaO   LOI    SM   2 d  Blaine  90 m R  28 d
# 0     61.77  3.16  2.44  21.3    3290     2.7  46.5
# 1     61.93  3.33  2.38  21.3    3320     4.1  45.9
# 2     60.93  2.88  2.36  20.5    3290     3.2  46.4
# 3     61.84  3.42  2.37  21.9    3340     3.5  47.3
# 4     61.65  3.28  2.41  22.0    3160     3.5  46.3
# ...     ...   ...   ...   ...     ...     ...   ...
# 1439  59.51  2.91  2.32  21.6    3150     4.8  47.0
# 1440  59.42  2.54  2.35  17.6    3160     1.8  44.4
# 1441  59.74  2.90  2.31  21.0    3230     1.6  47.2
# 1447  59.73  2.77  2.26  19.5    3570     3.8  47.1
# 1448  59.85  2.60  2.27  22.6    3210     4.1  48.3
#
# [1353 rows x 7 columns]

# %%
x_train = df_no_outliers[filtered_feats]
y_train = df_no_outliers["28 d"]

# %% [markdown]
# ## I will use Z-score method to standerdize the features to zero mean and 1 standard deviations:
# 1. as blaine feature's range is in thousands and the other features are in percentages
# 2. this will lead to misleading of coefficient estimations and feature importance

# %%
x_train,x_test , y_train,  y_test= train_test_split(x_train, y_train, test_size=0.50, random_state=42)

scaler = StandardScaler()

# Fit scaler on training data and transform both train and test sets
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train_scaled , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Let's see which feature affect the most

# %%
pd.Series(model.coef_ , index = x_train.columns).sort_values().plot(kind = "barh")
plt.title("Feature Importance")
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# ## everything is great till now

# %% [markdown]
# Let's Calculate the MEAN ABSOLUTE ERROR for our model for training and testing set

# %%
y_pred_train = model.predict(x_train_scaled)
mean_absolute_error(y_train ,y_pred_train)
# Out:
# 0.6731424111015224

# %%
y_pred_test = model.predict(x_test_scaled)
mean_absolute_error(y_test ,y_pred_test)
# Out:
# 0.6828267807422593

# %% [markdown]
# ## Now Let's Try Out Our MODEL and see the RESULTS compared to our training data

# %%
pd.DataFrame({
    "y_train" : y_test, 
    "y_pred" : model.predict(x_test_scaled)
}).head(10)
# Out:
#       y_train     y_pred
# 1009     47.1  45.487230
# 784      45.6  46.024916
# 19       45.7  45.675566
# 298      45.2  45.892028
# 602      44.8  44.942882
# 1041     44.8  45.719046
# 518      45.4  45.670466
# 797      45.5  45.408613
# 919      42.8  44.553857
# 147      47.8  46.873715

# %% [markdown]
# ## Let's see the parity plot

# %%
plt.plot([min(y_train) , max(y_train)] , [min(y_train) , max(y_train)], color = "blue")
plt.scatter(y_train ,model.predict(x_train_scaled), color = "black", label = "train")
plt.scatter(y_test , model.predict(x_test_scaled), color = "red" , label = "test")
plt.xlabel("y_actual")
plt.ylabel("y_predicted")
plt.title("parity plot")
plt.legend()

# %% [markdown]
# The model doesn't perform well on Linear (Mathematical model) and shows high error in both upper strengthes and lower strengthes which isn't good

# %% [markdown]
# I Will save the model

# %%
import joblib
with open("Linear_Reg_28d_strength_model.joblib", "wb") as file:
    joblib.dump(model, file)

# %%
with open("Linear_Reg_28d_strength_model_scaler.joblib", "wb") as file:
    joblib.dump(scaler, file)

# %% [markdown]
# ## I will try out if any polynomial degree will work "JUST FOR FUN"

# %%
def plot_train_cv_mses(degrees, train_mses, cv_mses, title , degrees_ = range(1,11)):
    degrees = degrees_
    plt.plot(degrees, train_mses, marker='o', c='r', label='training MSEs'); 
    plt.plot(degrees, cv_mses, marker='o', c='b', label='CV MSEs'); 
    plt.title(title)
    plt.xlabel("degree"); 
    plt.ylabel("MAE"); 
    plt.legend()
    plt.show()

# %%
# Initialize lists containing the lists, models, and scalers
train_maes = []
cv_maes = []
models = []
scalers = []

# Loop over 10 times. Each adding one more degree of polynomial higher than the last.
for degree in range(1,11):
    
    # Add polynomial features to the training set
    poly = PolynomialFeatures(degree, include_bias=False)
    X_train_mapped = poly.fit_transform(x_train)
    scaler  = StandardScaler()
    X_train_mapped = poly.fit_transform(x_train)
    X_train_mapped_scaled = scaler.fit_transform(X_train_mapped)

    # Create and train the model
    pol_model = LinearRegression()
    pol_model.fit( X_train_mapped_scaled, y_train)
    models.append(pol_model)
    
    # Compute the training MSE
    yhat = pol_model.predict(X_train_mapped_scaled)
    train_mae = mean_absolute_error(y_train, yhat)
    train_maes.append(train_mae)
    
    # Add polynomial features and scale the cross validation set
    poly = PolynomialFeatures(degree, include_bias=False)
    X_cv_mapped = poly.fit_transform(x_test)
    X_cv_mapped_scaled = scaler.fit_transform(X_cv_mapped)
    # Compute the cross validation MSE
    yhat = pol_model.predict(X_cv_mapped_scaled)
    cv_mse = mean_absolute_error(y_test, yhat)
    cv_maes.append(cv_mse)
    
# Plot the results
degrees=range(1,6)
plot_train_cv_mses(degrees, train_maes, cv_maes, title="degree of polynomial vs. train and CV MSEs")

# %% [markdown]
# DEGREE 1 IS THE BEST

# %%
res_best_model = pd.DataFrame({"y_test" : y_test , "y_pred_test" : model.predict(x_test_scaled)})
res_best_model["pct error"] = np.abs(res_best_model["y_test"] - res_best_model["y_pred_test"])*100 / res_best_model["y_test"]
sns.histplot(res_best_model["pct error"],stat = "percent")
# Out:
# <Axes: xlabel='pct error', ylabel='Percent'>

# %%
plt.scatter(y_pred_train-y_train , y_train)
plt.xlabel("Residues")
plt.ylabel("y_train")
# Out:
# Text(0, 0.5, 'y_train')

# %%
sns.displot(y_pred_train-y_train , kind = "kde")

# %%
res_best_model = pd.DataFrame({"y_test" : y_train , "y_pred_test" :model.predict(x_train_scaled)})
res_best_model["pct error"] = np.abs(res_best_model["y_test"] - res_best_model["y_pred_test"])*100 / res_best_model["y_test"]
sns.histplot(res_best_model["pct error"],stat = "percent")
# Out:
# <Axes: xlabel='pct error', ylabel='Percent'>

# %% [markdown]
# ## Achieving Max of 6.5% error and MAE of 0.68 on the test set Using only Linear Regression isn't that good but I'm not Satisfied yet So let's try out XGBOOST Regressor

# %% [markdown]
# I Love Visualizing Errors vs the hyperparameter rather than Grid/Randomized Search or even Bayesian Optimization as it gives me a satisfaction from the inside on how that hyper parameter affects the accuracy of my model

# %% [markdown]
# ## Note I will not Use the scaled features for the trees as it'll not make any difference

# %%
error_train = []
error_test  = [] 
estimators = range(10 , 510 , 1)
for estimator in estimators:
    model = XGBRegressor(n_estimators = estimator ,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(estimators , error_train , color = "blue" , label = "train acc")
plt.plot(estimators , error_test , color = "red" , label = "test acc")
plt.xlabel("n_estimators")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"best estimator is {estimators[np.argmin(error_test)]}")
# Out:
# train error 0.4685877286470853
# test error 0.7074733485836955
# best estimator is 15

# %% [markdown]
# ## There's an overfitting problem so we need regulariztion

# %%
error_train = []
error_test  = [] 
depths = range(1 , 21 , 1)
for depth in depths:
    model = XGBRegressor(n_estimators = 15 , max_depth = depth,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(depths , error_train , color = "blue" , label = "train error")
plt.plot(depths , error_test , color = "red" , label = "test error")
plt.xlabel("max_depth")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"max depth is {depths[np.argmin(error_test)]}")
# Out:
# train error 0.6277967328855978
# test error 0.693059212498411
# max depth is 2

# %%
error_train = []
error_test  = [] 
learning_rate = np.linspace(1e-3 , 2 , 1000)
for lr in learning_rate:
    model = XGBRegressor(n_estimators = 15 , max_depth = 2, learning_rate = lr ,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(learning_rate , error_train , color = "blue" , label = "train error")
plt.plot(learning_rate , error_test , color = "red" , label = "test error")
plt.xlabel("learning rate")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"learning rate is {learning_rate[np.argmin(error_test)]}")
# Out:
# train error 0.5866686781482584
# test error 0.6888812296489286
# learning rate is 0.3491741741741742

# %%
error_train = []
error_test  = [] 
alphas = np.linspace(1e-10 , 50 ,1000)
for alpha in alphas:
    model = XGBRegressor(n_estimators = 15 , max_depth = 2, learning_rate =0.34917  ,reg_alpha = alpha ,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(alphas , error_train , color = "blue" , label = "train error")
plt.plot(alphas , error_test , color = "red" , label = "test error")
plt.xlabel("reg alpha")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"reg alpha is {alphas[np.argmin(error_test)]}")
# Out:
# train error 0.5866695020325791
# test error 0.688880676630686
# reg alpha is 1e-10

# %%
error_train = []
error_test  = [] 
lambdas = np.linspace(0.001 , 2 ,1000)
for lambda_ in lambdas:
    model = XGBRegressor(n_estimators = 15 , max_depth = 2, reg_alpha = 1e-10 , reg_lambda = lambda_ , learning_rate =0.34917 ,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(lambdas , error_train , color = "blue" , label = "train error")
plt.plot(lambdas , error_test , color = "red" , label = "test error")
plt.xlabel("reg lambda")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"reg lambda is {lambdas[np.argmin(error_test)]}")
# Out:
# train error 0.5700344446848131
# test error 0.6783682332236386
# reg lambda is 0.02101001001001001

# %% [markdown]
# Now the final XGBOOST model is here

# %%
XGB_model = XGBRegressor(n_estimators = 15 , max_depth = 2, reg_alpha = 1e-10 , reg_lambda = lambda_ , learning_rate =0.34917 ,random_state = 42)
XGB_model.fit(x_train , y_train)

y_pred_train = XGB_model.predict(x_train)
y_pred_test  = XGB_model.predict(x_test)

# %%
pd.DataFrame({
    "y_train" : y_test, 
    "y_pred" : y_pred_test
})
# Out:
#       y_train     y_pred
# 1009     47.1  45.509579
# 784      45.6  45.725239
# 19       45.7  45.788349
# 298      45.2  46.163799
# 602      44.8  45.084122
# ...       ...        ...
# 637      45.1  45.227978
# 269      45.7  45.638889
# 440      44.6  45.638889
# 1437     45.5  45.459297
# 1165     46.5  45.725239
#
# [338 rows x 2 columns]

# %%
res_XGB_model = pd.DataFrame({"y_test" : y_test , "y_pred_test" : XGB_model.predict(x_test)})
res_XGB_model["pct error"] = np.abs(res_XGB_model["y_test"] - res_XGB_model["y_pred_test"])*100 / res_XGB_model["y_test"]
sns.histplot(res_XGB_model["pct error"],stat = "percent")
# Out:
# <Axes: xlabel='pct error', ylabel='Percent'>

# %%
res_XGB_model = pd.DataFrame({"y_test" : y_train , "y_pred_test" : XGB_model.predict(x_train)})
res_XGB_model["pct error"] = np.abs(res_XGB_model["y_test"] - res_XGB_model["y_pred_test"])*100 / res_XGB_model["y_test"]
sns.histplot(res_XGB_model["pct error"],stat = "percent")
# Out:
# <Axes: xlabel='pct error', ylabel='Percent'>

# %%
plt.plot([min(y_train) , max(y_train)] , [min(y_train) , max(y_train)], color = "blue")
plt.scatter(y_train ,XGB_model.predict(x_train), color = "black", label = "train")
plt.scatter(y_test , XGB_model.predict(x_test), color = "red" , label = "test")
plt.xlabel("y_actual")
plt.ylabel("y_predicted")
plt.title("parity plot")
plt.legend()

# %%
pd.Series(XGB_model.feature_importances_ , index = x_train.columns).sort_values().plot(kind = "barh")
plt.title("Feature Importance for XGBOOST MODEL")
# Out:
# Text(0.5, 1.0, 'Feature Importance for XGBOOST MODEL')

# %% [markdown]
# ## XGB ACHIEVES Slightly HIGHER ACCURACY THAN REGRESSION EQUATION

# %% [markdown]
# ------

# %% [markdown]
# # It's time for Random Forest

# %%
error_train = []
error_test  = [] 
estimators = range(10 , 510 , 1)
for estimator in estimators:
    model = RandomForestRegressor(n_estimators = estimator ,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(estimators , error_train , color = "blue" , label = "train acc")
plt.plot(estimators , error_test , color = "red" , label = "test acc")
plt.xlabel("n_estimators")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"best estimator is {estimators[np.argmin(error_test)]}")
# Out:
# train error 0.25738324869154006
# test error 0.6877331531783375
# best estimator is 381

# %%
error_train = []
error_test  = [] 
depths = range(1 , 30 , 1)
for depth in depths:
    model = RandomForestRegressor(n_estimators = 381 , max_depth = depth,random_state = 42)
    model.fit(x_train , y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test  = model.predict(x_test)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))

plt.plot(depths , error_train , color = "blue" , label = "train error")
plt.plot(depths , error_test , color = "red" , label = "test error")
plt.xlabel("max_depth")
plt.ylabel("MAE")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"max depth is {depths[np.argmin(error_test)]}")
# Out:
# train error 0.2574392235733792
# test error 0.6876324631018753
# max depth is 22

# %% [markdown]
# ## There's an Obvious overfitting problem

# %%
RF_model = RandomForestRegressor(n_estimators = 381 , max_depth = 22,random_state = 42)
RF_model.fit(x_train , y_train)

y_pred_train = RF_model.predict(x_train)
y_pred_test  = RF_model.predict(x_test)

# %%
pd.Series(RF_model.feature_importances_ , index = x_train.columns).sort_values().plot(kind = "barh")
plt.title("Feature Importance for Random Forest MODEL")
# Out:
# Text(0.5, 1.0, 'Feature Importance for Random Forest MODEL')

# %%
plt.plot([min(y_train) , max(y_train)] , [min(y_train) , max(y_train)], color = "blue")
plt.scatter(y_train ,RF_model.predict(x_train), color = "black", label = "train")
plt.scatter(y_test , RF_model.predict(x_test), color = "red" , label = "test")
plt.xlabel("y_actual")
plt.ylabel("y_predicted")
plt.title("Random Forest parity plot")
plt.legend()

# %% [markdown]
# ------------------

# %% [markdown]
# ## Let's try KNN

# %%
error_train = []
error_test = []
ks = range(1 , 50)
for k in ks:
    knn_model = KNeighborsRegressor(n_neighbors=k)  
    knn_model.fit(x_train_scaled, y_train)

   
    y_pred_train = knn_model.predict(x_train_scaled)
    y_pred_test = knn_model.predict(x_test_scaled)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))


plt.plot(ks, error_train , color = "blue" , label = "train acc")
plt.plot(ks, error_test , color = "red" , label = "test acc")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"k is {ks[np.argmin(error_test)]}")
# Out:
# train error 0.6468047337278109
# test error 0.6990532544378699
# k is 10

# %%
knn_model = KNeighborsRegressor(n_neighbors=10)  
knn_model.fit(x_train_scaled , y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
plt.plot([min(y_train) , max(y_train)] , [min(y_train) , max(y_train)], color = "blue")
plt.scatter(y_train ,knn_model.predict(x_train_scaled), color = "black", label = "train")
plt.scatter(y_test , knn_model.predict(x_test_scaled), color = "red" , label = "test")
plt.xlabel("y_actual")
plt.ylabel("y_predicted")
plt.title("KNN parity plot")
plt.legend()

# %% [markdown]
# ## SVM

# %%
error_train = []
error_test = []
Cs = np.linspace(0.001 , 5 , 100)
for C in Cs:
    svr_model = SVR(kernel='rbf', C=C)
    svr_model.fit(x_train_scaled, y_train)

   
    y_pred_train = svr_model.predict(x_train_scaled)
    y_pred_test = svr_model.predict(x_test_scaled)

    error_train.append(mean_absolute_error(y_train , y_pred_train))
    error_test.append(mean_absolute_error(y_test , y_pred_test))


plt.plot(Cs, error_train , color = "blue" , label = "train acc")
plt.plot(Cs, error_test , color = "red" , label = "test acc")
plt.legend()

print(f"train error {error_train[np.argmin(error_test)]}")
print(f"test error {error_test[np.argmin(error_test)]}")
print(f"C is {Cs[np.argmin(error_test)]}")
# Out:
# train error 0.5168485195236865
# test error 0.6918052509303347
# C is 0.9604040404040403

# %%
svr_model = SVR(kernel='rbf', C=0.9604040404040403)
svr_model.fit(x_train_scaled, y_train)
# Out:
# SVR(C=0.9604040404040403)

# %%
plt.plot([min(y_train) , max(y_train)] , [min(y_train) , max(y_train)], color = "blue")
plt.scatter(y_train ,svr_model.predict(x_train_scaled), color = "black", label = "train")
plt.scatter(y_test , svr_model.predict(x_test_scaled), color = "red" , label = "test")
plt.xlabel("y_actual")
plt.ylabel("y_predicted")
plt.title("SVR parity plot")
plt.legend()

# %%
Models_results = pd.read_excel("D:/Book1.xlsx")
Models_results
# Out:
#                Model  Test MAE  Train MAE
# 0  Linear Regression  0.682827   0.673142
# 1            XGBOOST  0.678368   0.570034
# 2      Random Forest  0.687632   0.257439
# 3                KNN  0.699053   0.646805
# 4                SVR  0.691805   0.516849

# %%
plt.figure(figsize=(15,10))
sns.barplot(data = Models_results.sort_values(ascending=False,by = "Test MAE") , x = "Model" , y = "Test MAE" )
# Out:
# <Axes: xlabel='Model', ylabel='Test MAE'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = Models_results.sort_values(ascending=False,by = "Train MAE") , x = "Model" , y = "Train MAE" )
# Out:
# <Axes: xlabel='Model', ylabel='Train MAE'>
